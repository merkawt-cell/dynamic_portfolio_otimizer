# %% [markdown]
# # 📊 ETF Portfolio Database Builder
#
# Ce notebook construit une base de données complète d'ETF avec toutes les features nécessaires pour la sélection de portefeuille.
#
# **Features calculées:**
# - Rendement annualisé (CAGR) sur 1, 3, 5, 10 ans
# - Volatilité annualisée
# - Sharpe Ratio
# - Max Drawdown
# - Matrice de corrélation

# %% [markdown]
# ## 1. Installation et imports

# %%
# Installation
# !pip install pandas numpy yfinance openpyxl tqdm
# Out:
# Requirement already satisfied: pandas in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: yfinance in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (1.0)
# Requirement already satisfied: openpyxl in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: tqdm in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: requests>=2.31 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (4.25.6)
# Requirement already satisfied: websockets>=13.0 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: cffi>=1.12.0 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: et-xmlfile in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: pycparser in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kawtarmerno/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.3.0)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta
from tqdm import tqdm
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Configuration

# %%
INPUT_FILE = "dataset/data_to_csv/etf_complete_data.xlsx"      # Ton fichier source
OUTPUT_FILE = "etf_portfolio_db.xlsx" # Fichier de sortie

YEARS_HISTORY = 10                     # Années d'historique à récupérer
RISK_FREE_RATE = 0.025                 # Taux sans risque (2.5%)

# %% [markdown]
# ## 3. Chargement du fichier source

# %%
df_source = pd.read_excel(INPUT_FILE)

tickers = df_source['Ticker'].dropna().unique().tolist()

df_source.head()
# Out:
#   Ticker                                    Name  \
# 0    IEV                   IEViShares Europe ETF
# 1    KXI  KXIiShares Global Consumer Staples ETF
# 2    NLR       NLRVanEck Uranium and Nuclear ETF
# 3    IXC            IXCiShares Global Energy ETF
# 4    TAN                    TANInvesco Solar ETF
#
#                                          Description % of Assets in Top 10  \
# 0  Explore IEV for FREE on ETF Database: Price, H...                19.97%
# 1  Explore KXI for FREE on ETF Database: Price, H...                50.91%
# 2  Explore NLR for FREE on ETF Database: Price, H...                55.20%
# 3  Explore IXC for FREE on ETF Database: Price, H...                59.86%
# 4  Explore TAN for FREE on ETF Database: Price, H...                59.39%
#
#   % of Assets in Top 15 % of Assets in Top 50 0.0% 0.15% 0.22% 0.35%  ...  \
# 0                26.09%                53.17%  NaN   NaN   NaN   NaN  ...
# 1                60.35%                88.82%  NaN   NaN   NaN   NaN  ...
# 2                75.29%               100.00%  NaN   NaN   NaN   NaN  ...
# 3                69.72%                99.79%  NaN   NaN   NaN   NaN  ...
# 4                75.56%               100.00%  NaN   NaN   NaN   NaN  ...
#
#   iShares US Transportation ETF  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   iShares iBonds 2026 Term High Yield and Income ETF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   iShares iBonds Dec 2026 Term Corporate ETF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   iShares iBonds Dec 2027 Term Corporate ETF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   iShares iBonds Dec 2028 Term Corporate ETF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   iShares iBonds Dec 2029 Term Corporate ETF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   iShares iBonds Dec 2029 Term Treasury ETF       © 2025 Åland Islands      ×
# 0                                       NaN  Market data           NaN  Close
# 1                                       NaN  Market data           NaN  Close
# 2                                       NaN  Market data           NaN  Close
# 3                                       NaN  Market data           NaN  Close
# 4                                       NaN  Market data           NaN  Close
#
# [5 rows x 8387 columns]

# %% [markdown]
# ## 4. Téléchargement des prix historiques (yfinance)

# %%
# 10ans de données
end_date = datetime.now()
start_date = end_date.replace(year=end_date.year - YEARS_HISTORY)

prices = yf.download(tickers, start=start_date, end=end_date, auto_adjust=True)['Close']
prices = prices.dropna(how='all')  # Supprimer les lignes où tous les prix sont NaN

min_days = int(252 * YEARS_HISTORY * 0.99)
prices_10y = prices.dropna(axis=1, thresh=min_days)

print(prices_10y.shape)
# Out:
# [*********************100%***********************]  386 of 386 completed
# (2515, 227)

# %%
prices_clean = prices_10y.dropna(axis=1, how="all")
prices_clean.head()
prices_clean.shape
# Out:
# (2515, 227)

# %% [markdown]
# # Téléchargement des volumes historiques

# %%
# Download volume data for tickers with 10Y prices
volumes = yf.download(
    tickers=prices_10y.columns.tolist(),
    start=start_date,
    end=end_date
)['Volume']

# Drop columns where volume is all NaN (just like prices)
volumes_10y = volumes.dropna(axis=1, thresh=min_days)

# Average daily volume over last year
TRADING_DAYS_PER_YEAR = 252
avg_daily_volume = volumes_10y.tail(TRADING_DAYS_PER_YEAR).mean()
df_liquidity = avg_daily_volume.reset_index()
df_liquidity.columns = ['Ticker', 'Avg_Daily_Volume']
# Out:
# [*********************100%***********************]  227 of 227 completed

# %% [markdown]
# ## 5. Calcul des rendements journaliers

# %%
# Rendements journaliers
returns = prices_10y.pct_change().dropna()
returns
# Out:
# Ticker          AGGY      AIRR       AOA       AOK       AOM       AOR  \
# Date
# 2016-01-05  0.000000 -0.000619  0.001354  0.000953  0.000000  0.000780
# 2016-01-06  0.004591 -0.009908 -0.013069 -0.001905 -0.004721 -0.007533
# 2016-01-07  0.000000 -0.038149 -0.017808 -0.007634 -0.008598 -0.013086
# 2016-01-08  0.000000  0.000260 -0.009065 -0.002244 -0.004785 -0.007955
# 2016-01-11  0.000691 -0.015861  0.000469 -0.002248  0.000000  0.000267
# ...              ...       ...       ...       ...       ...       ...
# 2025-12-26 -0.001155 -0.003346 -0.000443  0.002978  0.000417  0.000459
# 2025-12-29  0.000907 -0.007109 -0.000443 -0.000247 -0.001042 -0.001375
# 2025-12-30  0.000226 -0.009845 -0.001109  0.000247 -0.000835 -0.000459
# 2025-12-31 -0.002491 -0.012554 -0.005552 -0.006929 -0.003341 -0.004746
# 2026-01-02 -0.001135  0.032547  0.005471  0.004735  0.002514  0.004307
#
# Ticker          ARKQ      ARKW      BOND      CEMB  ...       WTV       XAR  \
# Date                                                ...
# 2016-01-05  0.004255  0.006688  0.001826 -0.010927  ...  0.002565  0.008424
# 2016-01-06 -0.019597 -0.011515  0.002782 -0.003900  ... -0.013433 -0.009873
# 2016-01-07 -0.017288 -0.037634 -0.002201  0.006089  ... -0.021073 -0.024928
# 2016-01-08 -0.034085 -0.010242  0.001151 -0.002161  ... -0.013413 -0.014749
# 2016-01-11 -0.029539 -0.022577 -0.001628  0.000000  ...  0.004364  0.003593
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-12-26 -0.017403 -0.002813  0.000000 -0.000436  ...  0.000988 -0.016444
# 2025-12-29 -0.008540 -0.009295  0.001282 -0.000872  ... -0.001910 -0.006371
# 2025-12-30 -0.005168 -0.007585 -0.000107  0.001527  ... -0.000638 -0.006575
# 2025-12-31 -0.007273 -0.009521 -0.002465 -0.001089  ... -0.007193 -0.008222
# 2026-01-02  0.032967  0.009409 -0.000537 -0.000872  ...  0.008253  0.037970
#
# Ticker          XCEM      XMHQ      XMMO      XNTK       XSD      XSOE  \
# Date
# 2016-01-05  0.000000  0.001390  0.004452 -0.001898 -0.009743  0.000000
# 2016-01-06  0.000000 -0.022216 -0.008524 -0.013501 -0.026001 -0.036221
# 2016-01-07  0.000000 -0.020733 -0.034388 -0.026600 -0.032708 -0.018283
# 2016-01-08  0.000000 -0.006960 -0.011752 -0.013663 -0.016410 -0.020693
# 2016-01-11  0.000000 -0.017815 -0.012613  0.006826  0.006067  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2025-12-26  0.006607 -0.000764 -0.000565  0.000035 -0.006420  0.008678
# 2025-12-29  0.004201 -0.004489 -0.006854 -0.004105 -0.007284 -0.003574
# 2025-12-30  0.003399 -0.005373 -0.005549 -0.002701 -0.001658  0.002818
# 2025-12-31 -0.000521 -0.012057 -0.009443 -0.009870 -0.011009 -0.003066
# 2026-01-02  0.022941  0.014353  0.014228  0.006334  0.042786  0.025884
#
# Ticker            XT      ZROZ
# Date
# 2016-01-05  0.003163 -0.008132
# 2016-01-06 -0.015970  0.020542
# 2016-01-07 -0.023304  0.000442
# 2016-01-08 -0.012356  0.005295
# 2016-01-11 -0.006687 -0.018346
# ...              ...       ...
# 2025-12-26  0.001230 -0.006632
# 2025-12-29 -0.006229  0.003642
# 2025-12-30 -0.000569 -0.004385
# 2025-12-31 -0.008248 -0.011082
# 2026-01-02  0.006739 -0.004981
#
# [2514 rows x 227 columns]

# %% [markdown]
# ## 6. Calcul des métriques de performance

# %%
def calculate_metrics(prices_10y, returns, ticker):
    """
    Calcule toutes les métriques pour un ETF.
    """
    p = prices_10y[ticker].dropna()
    r = returns[ticker].dropna()

    if len(p) < 252:  # Minimum 1 an de données
        return None

    metrics = {'Ticker': ticker}

    # === RENDEMENTS ANNUALISÉS (CAGR) ===
    periods = {
        'Return_1Y': 252,
        'Return_3Y': 252 * 3,
        'Return_5Y': 252 * 5,
        'Return_10Y': 252 * 10
    }

    for name, days in periods.items():
        if len(p) >= 252:  # Minimum 1 year
            # Use the first available price in the period or the earliest if not enough
            start_idx = max(-days, -len(p))
            start_price = p.iloc[start_idx]
            end_price = p.iloc[-1]
            years = len(p.iloc[start_idx:]) / 252  # approximate years available
            cagr = (end_price / start_price) ** (1 / years) - 1
            metrics[name] = round(cagr * 100, 2)
        else:
            metrics[name] = np.nan

    # === VOLATILITÉ ANNUALISÉE ===
    metrics['Volatility_1Y'] = round(r.tail(252).std() * np.sqrt(252) * 100, 2)
    metrics['Volatility_10Y'] = round(r.std() * np.sqrt(252) * 100, 2)

    # === SHARPE RATIO ===
    annual_return = r.mean() * 252
    annual_vol = r.std() * np.sqrt(252)
    if annual_vol > 0:
        metrics['Sharpe_Ratio'] = round((annual_return - RISK_FREE_RATE) / annual_vol, 2)
    else:
        metrics['Sharpe_Ratio'] = np.nan

    # === MAX DRAWDOWN ===
    cummax = p.cummax()
    drawdown = (p - cummax) / cummax
    metrics['Max_Drawdown'] = round(drawdown.min() * 100, 2)

    # === SORTINO RATIO ===
    downside_returns = r[r < 0]
    if len(downside_returns) > 0 and downside_returns.std() > 0:
        downside_vol = downside_returns.std() * np.sqrt(252)
        metrics['Sortino_Ratio'] = round((annual_return - RISK_FREE_RATE) / downside_vol, 2)
    else:
        metrics['Sortino_Ratio'] = np.nan
    
     # === Quality Score ===
    # Base: 45% Return_10Y + 45% Sharpe_Ratio
    quality_score = 0.45 * metrics['Return_10Y'] + 0.45 * metrics['Sharpe_Ratio']

    # Add liquidity if available
    if df_liquidity is not None:
        vol_row = df_liquidity.loc[df_liquidity['Ticker'] == ticker]
        if not vol_row.empty:
            avg_vol_log = np.log1p(vol_row['Avg_Daily_Volume'].values[0])
            quality_score += 0.1 * avg_vol_log  # 10% weight for liquidity

    metrics['Quality_Score'] = round(quality_score, 2)

    return metrics

# %%
# Calculer les métriques pour tous les ETF
all_metrics = []

for ticker in tqdm(prices_10y.columns, desc="Calcul des métriques"):
    m = calculate_metrics(prices_10y, returns, ticker)
    if m:
        all_metrics.append(m)

df_metrics = pd.DataFrame(all_metrics)
df_metrics.head(10)
# Out:
# Calcul des métriques: 100%|██████████| 227/227 [00:00<00:00, 896.73it/s]
#   Ticker  Return_1Y  Return_3Y  Return_5Y  Return_10Y  Volatility_1Y  \
# 0   AGGY       7.26       5.42      -0.42        2.24           5.16
# 1   AIRR      32.08      33.10      24.61       20.46          27.41
# 2    AOA      20.24      17.62       9.42       10.03          13.46
# 3    AOK      11.79       9.74       3.58        5.19           6.56
# 4    AOM      13.57      11.34       4.78        6.17           8.01
# 5    AOR      16.95      14.47       7.11        8.12          10.39
# 6   ARKQ      53.71      44.35       9.73       21.01          36.56
# 7   ARKW      40.23      60.74       1.30       23.35          38.90
# 8   BOND       8.33       5.85       0.15        2.44           4.97
# 9   CEMB       8.77       7.84       1.72        4.32           4.06
#
#    Volatility_10Y  Sharpe_Ratio  Max_Drawdown  Sortino_Ratio  Quality_Score
# 0            5.47         -0.03        -20.97          -0.03           2.15
# 1           26.01          0.75        -42.37           1.05          10.87
# 2           13.56          0.59        -28.38           0.71           5.93
# 3            6.65          0.42        -18.93           0.51           3.71
# 4            7.89          0.48        -19.96           0.58           4.18
# 5           10.65          0.55        -22.95           0.68           5.15
# 6           29.43          0.71        -59.89           1.02          10.99
# 7           37.47          0.68        -80.01           0.92          12.05
# 8            5.06          0.01        -19.71           0.01           2.38
# 9            6.49          0.30        -20.84           0.33           3.15

# %% [markdown]
# # 7. Selection des ETF les moins corrélés avec les quality scores les plus élevés et return > 10%

# %%
returns_clean = returns[prices_10y.columns]
correlation_matrix = returns_clean.corr().abs()

upper = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
threshold = 0.8
to_keep = []
processed = set()
top_n = 2  # keep top 2 per correlated cluster

for col in corr_matrix.columns:
    if col in processed:
        continue

    # Find ETFs correlated above threshold
    correlated = upper.index[upper[col] > threshold].tolist()
    correlated.append(col)

    # Keep only ETFs that exist in returns_clean
    correlated = [t for t in correlated if t in returns_clean.columns]

    if correlated:
        # Sort by Quality_Score if available, else by Return_10Y
        if 'Quality_Score' in df_final.columns:
            top_etfs = df_final[df_final['Ticker'].isin(correlated)] \
                .sort_values('Quality_Score', ascending=False)['Ticker'].tolist()
        else:
            top_etfs = df_final[df_final['Ticker'].isin(correlated)] \
                .sort_values('Return_10Y', ascending=False)['Ticker'].tolist()

        # Keep top_n
        to_keep.extend(top_etfs[:top_n])

    processed.update(correlated)

# Filter metrics dataframe for the selected ETFs
selected_etfs = df_final[
    (df_final['Ticker'].isin(to_keep)) &
    (df_final['Return_10Y'] > 10)
].copy()

# Optional: sort by Quality_Score or Return_10Y
selected_etfs = selected_etfs.sort_values(
    'Quality_Score' if 'Quality_Score' in df_final.columns else 'Return_10Y',
    ascending=False
)

print(f"✅ Final ETFs after correlation and Return_10Y filter: {len(selected_etfs)}")
selected_etfs.head(20)
# Out:
# ✅ Final ETFs after correlation and Return_10Y filter: 12
#     Ticker                                               Name  Expense Ratio  \
# 70     PSI                         Invesco Semiconductors ETF           0.56
# 54     IYW                        iShares U.S. Technology ETF           0.38
# 39    RING                iShares MSCI Global Gold Miners ETF           0.39
# 42    PICK  iShares MSCI Global Metals & Mining Producers ETF           0.39
# 2      NLR                     VanEck Uranium and Nuclear ETF           0.56
# 82    UTES                        Virtus Reaves Utilities ETF           0.49
# 41     LIT                Global X Lithium & Battery Tech ETF           0.75
# 44    NANR      SPDR S&P North American Natural Resources ETF           0.35
# 36    GUNR  FlexShares Morningstar Global Upstream Natural...           0.46
# 101   XCEM                      Columbia EM Core ex-China ETF           0.16
# 155   PTLC                  Pacer Trendpilot US Large Cap ETF           0.60
# 80     FXU                First Trust Utilities AlphaDEX Fund           0.64
#
#      Annual Dividend Yield  Asset Class Asset Class Size Asset Class Style  \
# 70                    0.09       Equity        Multi-Cap            Growth
# 54                    0.14       Equity        Large-Cap            Growth
# 39                    0.84       Equity        Large-Cap             Blend
# 42                    2.89       Equity        Large-Cap             Blend
# 2                     2.51       Equity        Multi-Cap             Value
# 82                    1.41       Equity        Multi-Cap             Blend
# 41                    0.41       Equity        Micro-Cap             Blend
# 44                    1.77       Equity        Large-Cap             Blend
# 36                    3.51       Equity        Large-Cap             Blend
# 101                    NaN       Equity        Multi-Cap             Blend
# 155                   0.63  Multi-Asset        Large-Cap             Blend
# 80                    2.28       Equity          Mid-Cap             Value
#
#       Region (General) Region (Specific)  \
# 70       North America              U.S.
# 54       North America              U.S.
# 39   Developed Markets             Broad
# 42   Developed Markets             Broad
# 2    Developed Markets             Broad
# 82       North America              U.S.
# 41   Developed Markets             Broad
# 44       North America             Broad
# 36   Developed Markets             Broad
# 101   Emerging Markets             Broad
# 155      North America              U.S.
# 80       North America              U.S.
#
#                                               Segment  ...  Return_3Y  \
# 70                        Equity: U.S. Semiconductors  ...      37.05
# 54                Equity: U.S. Information Technology  ...      40.74
# 39                         Equity: Global Gold Miners  ...      50.85
# 42                     Equity: Global Metals & Mining  ...      12.29
# 2                       Equity: Global Nuclear Energy  ...      38.26
# 82                             Equity: U.S. Utilities  ...      21.93
# 41                            Equity: Global Mobility  ...       5.62
# 44            Equity: North America Natural Resources  ...      11.11
# 36                   Equity: Global Natural Resources  ...       5.92
# 101  Equity: Emerging Markets Ex-China - Total Market  ...      18.33
# 155                          Equity: U.S. - Large Cap  ...      15.19
# 80                             Equity: U.S. Utilities  ...      13.73
#
#      Return_5Y Return_10Y Volatility_1Y Volatility_10Y  Sharpe_Ratio  \
# 70       19.53      26.53         43.40          34.23          0.79
# 54       18.85      23.29         27.78          24.96          0.86
# 39       22.02      22.28         38.78          36.61          0.66
# 42       12.41      16.80         24.94          28.74          0.60
# 2        25.12      14.79         40.57          22.31          0.62
# 82       17.66      14.47         24.69          19.76          0.66
# 41        2.53      14.45         31.87          30.34          0.51
# 44       18.87      13.58         21.27          24.02          0.55
# 36       11.36      11.22         16.65          20.83          0.50
# 101       8.29      10.94         16.97          19.44          0.50
# 155      12.44      10.52         12.03          13.05          0.64
# 80       12.94      10.37         15.29          18.36          0.49
#
#      Max_Drawdown  Sortino_Ratio  Quality_Score  Meets_Return_Criteria
# 70         -44.85           1.07          13.40                   True
# 54         -39.44           1.11          12.24                   True
# 39         -52.04           0.98          11.62                   True
# 42         -52.73           0.83           9.10                   True
# 2          -34.35           0.81           8.24                   True
# 82         -35.39           0.80           8.01                   True
# 41         -65.91           0.74           7.99                   True
# 44         -49.15           0.71           7.43                   True
# 36         -43.04           0.62           6.59                   True
# 101        -40.92           0.64           6.36                   True
# 155        -26.63           0.69           6.28                   True
# 80         -34.81           0.63           6.20                   True
#
# [12 rows x 26 columns]

# %% [markdown]
# ## 8. Fusion avec les données source

# %%
# Colonnes utiles du fichier source
source_cols = [
    'Ticker', 'Name',
    'Expense Ratio', 'Annual Dividend Yield',
    'Asset Class', 'Asset Class Size', 'Asset Class Style',
    'Region (General)', 'Region (Specific)',
    'Segment', 'Beta',
    'Number of Holdings', 'Inception',
    'Issuer', 'Index Tracked'
]

# Garder seulement les colonnes qui existent
existing_cols = [c for c in source_cols if c in df_source.columns]
df_source_clean = df_source[existing_cols].copy()

# Nettoyer les pourcentages
pct_cols = ['Expense Ratio', 'Annual Dividend Yield']
for col in pct_cols:
    if col in df_source_clean.columns:
        df_source_clean[col] = df_source_clean[col].astype(str).str.replace('%', '')
        df_source_clean[col] = pd.to_numeric(df_source_clean[col], errors='coerce')

# Nettoyer le nom
if 'Name' in df_source_clean.columns:
    df_source_clean['Name'] = df_source_clean.apply(
        lambda row: row['Name'][len(row['Ticker']):] if str(row['Name']).startswith(str(row['Ticker'])) else row['Name'],
        axis=1
    )

print(f"✅ Données source nettoyées: {len(existing_cols)} colonnes")
# Out:
# ✅ Données source nettoyées: 15 colonnes

# %%
df_final = pd.merge(df_source_clean, df_metrics, on='Ticker', how='inner')
df_final['Meets_Return_Criteria'] = df_final['Return_10Y'] >= 10

print(f"✅ ETFs with Return_10Y >= 10%: {len(selected_etfs)}")
# Out:
# ✅ ETFs with Return_10Y >= 10%: 12

# %%
# Merge source info
selected_etfs = selected_etfs.merge(df_source_clean, on='Ticker', how='left')

# Merge liquidity info
selected_etfs = selected_etfs.merge(df_liquidity, on='Ticker', how='left')

print(f"✅ Final ETFs after merging all data: {len(selected_etfs)}")
selected_etfs.head(20)
# Out:
# ✅ Final ETFs after merging all data: 12
#    Ticker                                             Name_x  Expense Ratio_x  \
# 0     PSI                         Invesco Semiconductors ETF             0.56
# 1     IYW                        iShares U.S. Technology ETF             0.38
# 2    RING                iShares MSCI Global Gold Miners ETF             0.39
# 3    PICK  iShares MSCI Global Metals & Mining Producers ETF             0.39
# 4     NLR                     VanEck Uranium and Nuclear ETF             0.56
# 5    UTES                        Virtus Reaves Utilities ETF             0.49
# 6     LIT                Global X Lithium & Battery Tech ETF             0.75
# 7    NANR      SPDR S&P North American Natural Resources ETF             0.35
# 8    GUNR  FlexShares Morningstar Global Upstream Natural...             0.46
# 9    XCEM                      Columbia EM Core ex-China ETF             0.16
# 10   PTLC                  Pacer Trendpilot US Large Cap ETF             0.60
# 11    FXU                First Trust Utilities AlphaDEX Fund             0.64
#
#     Annual Dividend Yield_x Asset Class_x Asset Class Size_x  \
# 0                      0.09        Equity          Multi-Cap
# 1                      0.14        Equity          Large-Cap
# 2                      0.84        Equity          Large-Cap
# 3                      2.89        Equity          Large-Cap
# 4                      2.51        Equity          Multi-Cap
# 5                      1.41        Equity          Multi-Cap
# 6                      0.41        Equity          Micro-Cap
# 7                      1.77        Equity          Large-Cap
# 8                      3.51        Equity          Large-Cap
# 9                       NaN        Equity          Multi-Cap
# 10                     0.63   Multi-Asset          Large-Cap
# 11                     2.28        Equity            Mid-Cap
#
#    Asset Class Style_x Region (General)_x Region (Specific)_x  \
# 0               Growth      North America                U.S.
# 1               Growth      North America                U.S.
# 2                Blend  Developed Markets               Broad
# 3                Blend  Developed Markets               Broad
# 4                Value  Developed Markets               Broad
# 5                Blend      North America                U.S.
# 6                Blend  Developed Markets               Broad
# 7                Blend      North America               Broad
# 8                Blend  Developed Markets               Broad
# 9                Blend   Emerging Markets               Broad
# 10               Blend      North America                U.S.
# 11               Value      North America                U.S.
#
#                                            Segment_x  ...  Asset Class Style  \
# 0                        Equity: U.S. Semiconductors  ...             Growth
# 1                Equity: U.S. Information Technology  ...             Growth
# 2                         Equity: Global Gold Miners  ...              Blend
# 3                     Equity: Global Metals & Mining  ...              Blend
# 4                      Equity: Global Nuclear Energy  ...              Value
# 5                             Equity: U.S. Utilities  ...              Blend
# 6                            Equity: Global Mobility  ...              Blend
# 7            Equity: North America Natural Resources  ...              Blend
# 8                   Equity: Global Natural Resources  ...              Blend
# 9   Equity: Emerging Markets Ex-China - Total Market  ...              Blend
# 10                          Equity: U.S. - Large Cap  ...              Blend
# 11                            Equity: U.S. Utilities  ...              Value
#
#      Region (General) Region (Specific)  \
# 0       North America              U.S.
# 1       North America              U.S.
# 2   Developed Markets             Broad
# 3   Developed Markets             Broad
# 4   Developed Markets             Broad
# 5       North America              U.S.
# 6   Developed Markets             Broad
# 7       North America             Broad
# 8   Developed Markets             Broad
# 9    Emerging Markets             Broad
# 10      North America              U.S.
# 11      North America              U.S.
#
#                                              Segment  Beta  \
# 0                        Equity: U.S. Semiconductors  1.57
# 1                Equity: U.S. Information Technology  1.23
# 2                         Equity: Global Gold Miners  0.50
# 3                     Equity: Global Metals & Mining  1.09
# 4                      Equity: Global Nuclear Energy  0.75
# 5                             Equity: U.S. Utilities  0.73
# 6                            Equity: Global Mobility  1.05
# 7            Equity: North America Natural Resources  0.75
# 8                   Equity: Global Natural Resources  0.72
# 9   Equity: Emerging Markets Ex-China - Total Market  0.84
# 10                          Equity: U.S. - Large Cap  0.57
# 11                            Equity: U.S. Utilities  0.67
#
#     Number of Holdings     Inception  \
# 0                 31.0  Jun 23, 2005
# 1                143.0  May 15, 2000
# 2                 43.0  Jan 31, 2012
# 3                230.0  Jan 31, 2012
# 4                 27.0  Aug 13, 2007
# 5                 20.0  Sep 23, 2015
# 6                 41.0  Jul 22, 2010
# 7                176.0  Dec 15, 2015
# 8                120.0  Sep 16, 2011
# 9                329.0  Sep 02, 2015
# 10               504.0  Jun 11, 2015
# 11                41.0  May 08, 2007
#
#                                       Issuer  \
# 0                                    Invesco
# 1                            BlackRock, Inc.
# 2                            BlackRock, Inc.
# 3                            BlackRock, Inc.
# 4                                     VanEck
# 5                 Virtus Investment Partners
# 6   Mirae Asset Global Investments Co., Ltd.
# 7                               State Street
# 8                       Northern Trust Corp.
# 9                       Ameriprise Financial
# 10                            Pacer Advisors
# 11                               First Trust
#
#                                         Index Tracked  Avg_Daily_Volume_y
# 0             Dynamic Semiconductors Intellidex Index        60858.730159
# 1                     Dow Jones U.S. Technology Index       923192.460317
# 2   MSCI ACWI Select Gold Miners Investable Market...       416807.539683
# 3   MSCI ACWI Select Metals & Mining Producers Ex ...       313818.253968
# 4                MVIS Global Uranium & Nuclear Energy       460709.920635
# 5                                   ACTIVE - No Index       172829.365079
# 6         Stuttgart Solactive AG Global Lithium (USD)       299282.142857
# 7      S&P BMI North American Natural Resources Index        43401.984127
# 8   Morningstar Global Upstream Natural Resources ...       519331.349206
# 9                MSCI Emerging Markets ex China Index       191353.968254
# 10              Pacer Trendpilot U.S. Large Cap Index       296423.015873
# 11                        StrataQuant Utilities Index       491155.952381
#
# [12 rows x 56 columns]

# %%
# Aperçu de la base finale
display_cols = ['Ticker', 'Name', 'Return_10Y', 'Volatility_10Y', 'Sharpe_Ratio', 'Max_Drawdown', 'Meets_Return_Criteria']
df_final[display_cols].sort_values('Return_10Y', ascending=False).head(15)
# Out:
#     Ticker                                               Name  Return_10Y  \
# 70     PSI                         Invesco Semiconductors ETF       26.53
# 66     XSD            State Street SPDR S&P Semiconductor ETF       23.42
# 65    ARKW                   ARK Next Generation Internet ETF       23.35
# 54     IYW                        iShares U.S. Technology ETF       23.29
# 53     VGT                Vanguard Information Technology ETF       22.84
# 55    FTEC     Fidelity MSCI Information Technology Index ETF       22.61
# 57     IGM                   iShares Expanded Tech Sector ETF       22.40
# 39    RING                iShares MSCI Global Gold Miners ETF       22.28
# 67    XNTK              State Street SPDR NYSE Technology ETF       22.11
# 58     IXN                            iShares Global Tech ETF       21.89
# 43    SLVP              iShares MSCI Global Silver Miners ETF       21.35
# 173   ARKQ           ARK Autonomous Technology & Robotics ETF       21.01
# 27    AIRR  First Trust RBA American Industrial Renaissanc...       20.46
# 64    QTEC  First Trust NASDAQ-100 Technology Sector Index...       19.28
# 45    SGDM                             Sprott Gold Miners ETF       19.16
#
#      Volatility_10Y  Sharpe_Ratio  Max_Drawdown  Meets_Return_Criteria
# 70            34.23          0.79        -44.85                   True
# 66            34.33          0.71        -42.27                   True
# 65            37.47          0.68        -80.01                   True
# 54            24.96          0.86        -39.44                   True
# 53            24.44          0.86        -35.07                   True
# 55            24.53          0.85        -34.95                   True
# 57            24.38          0.85        -40.68                   True
# 39            36.61          0.66        -52.04                   True
# 67            26.42          0.79        -48.28                   True
# 58            24.07          0.84        -36.30                   True
# 43            41.75          0.61        -62.04                   True
# 173           29.43          0.71        -59.89                   True
# 27            26.01          0.75        -42.37                   True
# 64            27.31          0.69        -45.54                   True
# 45            36.75          0.59        -49.69                   True

# %% [markdown]
# ## 9. Export vers Excel

# %%
# Créer le fichier Excel avec plusieurs onglets
with pd.ExcelWriter(OUTPUT_FILE, engine='openpyxl') as writer:

    # Onglet 1: Toutes les données
    df_final.to_excel(writer, sheet_name='ETF_Data', index=False)

    # Onglet 2: Matrice de corrélation
    correlation_matrix.to_excel(writer, sheet_name='Correlation_Matrix')

    # Onglet 3: ETF qualifiés (rendement > 10%)
    selected_etfs.to_excel(writer, sheet_name='Qualified_ETFs', index=False)

    # Onglet 4: Prix historiques
    prices.to_excel(writer, sheet_name='Price_History')

print(f"Fichier exporté: {OUTPUT_FILE}")
# Out:
# Fichier exporté: etf_portfolio_db.xlsx

# %% [markdown]
# Abdelhamid Test
